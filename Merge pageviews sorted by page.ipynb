# %%
# %run -i ./import_pageviews_sorted_by_page.py 'sorted_page/2017-12/part-00000.gz'

# %%
df.drop(columns=['reqbytes'], inplace=True)

# %%
df.head()
# Out:
#   lang                                               page           timestamp  \
# 0  (ja  Category%3A2808%E5%B9%B4%E3%81%AE%E3%83%86%E3%... 2007-12-14 15:00:00
# 1  (ja  Category%3A2808%E5%B9%B4%E3%81%AE%E3%83%86%E3%... 2007-12-14 16:00:00
# 2  (ja  %E4%BA%A4%E6%B8%89%E4%BA%BA%E3%80%9CTHE_NEGOTI... 2007-12-14 15:00:00
# 3   ?a  %E3%81%8A%E3%81%9B%E3%81%A3%E3%81%8B%E3%81%84_... 2007-12-19 19:00:00
# 4   ?a  %E3%83%9C%E3%83%96%E3%81%A8%E3%81%AF%E3%81%9F%... 2007-12-28 08:00:00
#
#    views
# 0      2
# 1      3
# 2      1
# 3      1
# 4      1

# %%
len(df)
# Out:
# 5459672

# %%
df.loc[(df['lang'] == 'en') & (df['page'] == 'Albert_Camus')].head()
# Out:
# Empty DataFrame
# Columns: [lang, page, timestamp, views]
# Index: []

# %%
# grouped_df = df.groupby(['lang','page', 'day'], as_index=False)
# grouped_df = df.groupby(['lang','page', pd.Grouper(freq="1D", key='timestamp')], as_index=False)
grouped_df = df.groupby(['lang','page', df.timestamp.dt.day], as_index=False)
grouped_df.head()
# Out:
#          lang                                               page  \
# 0         (ja  Category%3A2808%E5%B9%B4%E3%81%AE%E3%83%86%E3%...
# 1         (ja  Category%3A2808%E5%B9%B4%E3%81%AE%E3%83%86%E3%...
# 2         (ja  %E4%BA%A4%E6%B8%89%E4%BA%BA%E3%80%9CTHE_NEGOTI...
# 3          ?a  %E3%81%8A%E3%81%9B%E3%81%A3%E3%81%8B%E3%81%84_...
# 4          ?a  %E3%83%9C%E3%83%96%E3%81%A8%E3%81%AF%E3%81%9F%...
# 5          ?a               %E5%9C%9F%E5%B2%90%E9%BA%BB%E5%AD%90
# 6          ?a  %E6%99%82%E7%A9%BA%E6%88%A6%E5%A3%AB%E3%82%B9%...
# 7          ?a               %E7%AC%A0%E5%8E%9F%E7%AB%9C%E5%8F%B8
# 8          ?a  %E9%A3%9F%E3%82%8F%E3%81%9A%E5%AB%8C%E3%81%84%...
# 9         \en                            Infinite_monkey_theorem
# 10        \en                            Infinite_monkey_theorem
# 11       \www                                        Cedar_Point
# 12         aa                                               %241
# 13         aa                                               %241
# 14         aa                                               %241
# 15         aa                                               %241
# 16         aa                                               %241
# 17         aa                                               %241
# 18         aa                                               %241
# 19         aa                                               %241
# 20         aa                                               %241
# 21         aa                                               %241
# 22         aa                                               %241
# 23         aa     %2527Ir%25C2%25B7r%25C2%25B7ropinjtu%25C3%25B1
# 24         aa     %2527Ir%25C2%25B7r%25C2%25B7ropinjtu%25C3%25B1
# 25         aa     %2527Ir%25C2%25B7r%25C2%25B7ropinjtu%25C3%25B1
# 26         aa     %2527Ir%25C2%25B7r%25C2%25B7ropinjtu%25C3%25B1
# 27         aa     %2527Ir%25C2%25B7r%25C2%25B7ropinjtu%25C3%25B1
# 28         aa                                                %26
# 29         aa                                                %26
# ...       ...                                                ...
# 5459572    ar  %D8%AD%D8%A7%D8%AA%D9%85_%D8%A7%D9%84%D8%B7%D8...
# 5

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Desktop/pageviews/import-pageviews/import_pageviews_sorted_by_page.py in <module>()
# ----> 1 grouped_df['daily_total'] = grouped_df['views'].transform('sum')
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/groupby.py in transform(self, func, *args, **kwargs)
#    4078         # nuiscance columns
#    4079         if not result.columns.equals(obj.columns):
# -> 4080             return self._transform_general(func, *args, **kwargs)
#    4081
#    4082         return self._transform_fast(result, obj)
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/groupby.py in _transform_general(self, func, *args, **kwargs)
#    4053         concatenated = concat(applied, join_axes=[concat_index],
#    4054                               axis=self.axis, verify_integrity=False)
# -> 4055         return self._set_result_index_ordered(concatenated)
#    4056
#    4057     @Substitution(klass='DataFrame', selected='')
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/groupby.py in _set_result_index_ordered(self, result)
#     659
#     660         result.set_axis(self.obj._get_axis(self.axis), axis=self.axis,
# --> 661                         inplace=True)
#     662         return result
#     663
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/generic.py in set_axis(self, labels, axis, inplace)
#     550             inplace = True
#     551         if inplace:
# --> 552             setattr(self, self._get_axis_name(axis), labels)
#     553         else:
#     554             obj = self.copy()
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# ~/.virtualenvs/pageviews3/lib/python3.6/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3072             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    3073                              'new values have %d elements' %
# -> 3074                              (old_len, new_len))
#    3075
#    3076         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 5459664 elements, new values have 5459672 elements

# %%
df.head()
# Out:
#   lang                                               page           timestamp  \
# 0  (ja  Category%3A2808%E5%B9%B4%E3%81%AE%E3%83%86%E3%... 2007-12-14 15:00:00
# 1  (ja  Category%3A2808%E5%B9%B4%E3%81%AE%E3%83%86%E3%... 2007-12-14 16:00:00
# 2  (ja  %E4%BA%A4%E6%B8%89%E4%BA%BA%E3%80%9CTHE_NEGOTI... 2007-12-14 15:00:00
# 3   ?a  %E3%81%8A%E3%81%9B%E3%81%A3%E3%81%8B%E3%81%84_... 2007-12-19 19:00:00
# 4   ?a  %E3%83%9C%E3%83%96%E3%81%A8%E3%81%AF%E3%81%9F%... 2007-12-28 08:00:00
#
#    views
# 0      2
# 1      3
# 2      1
# 3      1
# 4      1

# %%
df.drop(columns=['views'], inplace=True)

# %%
df['date'] = df['timestamp'].transform(lambda ts: ts.date())

# %%
df.drop(columns=['timestamp'], inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()

# %%
df.loc[(df['lang'] == 'en') & (df['page'] == 'Albert_Camus')].head(n=50)
